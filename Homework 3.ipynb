# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Scheduling Algorithm Analysis

# %%
header = [
    'algorithm',
    'time_quantum',
    'avg_turn_time',
    'avg_wait_time',
    'longest_wait_time',
    'tot_run_time_all',
    'tot_num_cont_switch'
]
df = pd.read_csv('scheduler_statistics.csv',names=stats)

# %%
# Time Quantum of 0 means that process runned until completion
df
# Out:
#      algorithm  time_quantum  avg_turn_time  avg_wait_time  longest_wait_time  \
# 0         FCFS             0    2984.428571    2594.928571               4972
# 1          SJN             0    2594.857143    2205.357143               4922
# 2     Priority             0    3192.214286    2802.714286               5251
# 3    RR-FCFS 1            10    5587.285714    5197.785714               5995
# 4    RR-FCFS 2           100    4853.571429    4464.071429               5050
# 5    RR-FCFS 3          1000    2984.428571    2594.928571               4972
# 6      RR-SRTN            50    2689.142857    2299.642857               5128
# 7  RR-Priority            50    3513.285714    3123.785714               5470
#
#    tot_run_time_all  tot_num_cont_switch
# 0              5481                   14
# 1              5481                   14
# 2              5481                   14
# 3              6549                  548
# 4              5581                   64
# ...

# %% [markdown]
# ### Average Wait Time

# %%
sns.set(style="whitegrid")
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(10, 12))

x = np.array(df['algorithm'])
y = np.array(df['avg_wait_time'])
sort_y = y.argsort()

sns.barplot(x[sort_y],y=y[sort_y],palette="BuGn_r",ax=ax1)
ax1.set_ylabel("Total Average Wait Time")


y = np.array(df['avg_turn_time'])
sort_y = y.argsort()

sns.barplot(x[sort_y],y=y[sort_y],palette="Blues",ax=ax2)
ax2.set_ylabel("Average TurnAround Time")

y= np.array(df['tot_run_time_all'])
sort_y = y.argsort()

sns.barplot(x[sort_y],y=y[sort_y],palette="GnBu_d",ax=ax3)
ax3.set_ylabel("Total Run Time All")

# Finalize the plot

plt.tight_layout(h_pad=2)
